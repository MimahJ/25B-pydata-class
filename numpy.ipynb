# %%
import pandas as pd

sales_data = pd.read_csv('Sales.csv')
sales_data.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#    Selling Price  Original Price                Mobile  Discount  \
# 0          19330           20999  SAMSUNG GALAXY M31S       1669
# 1          10199           10199             Nokia 3.2         0
# 2           6999            7999            realme C2       1000
# 3          12999           12999        Infinix Note 5         0
# 4          49900           49900      Apple iPhone 11          0
#
#    discount percentage
# 0             7.947998
# 1             0.000000
# 2            12.501563
# 3             0.000000
# 4             0.000000

# %%
sales_data.iloc[:,0].nunique()
# Out:
# 17

# %%
sales_data.iloc[sales_data.iloc[:,7].idxmax()]
# Out:
# Brands                                    Apple
# Models                       iPhone 13 Pro Max
# Colors                                     Gold
# Memory                                     6 GB
# Storage                                    1 TB
# Camera                                      Yes
# Rating                                      NaN
# Selling Price                            179900
# Original Price                           179900
# Mobile                 Apple iPhone 13 Pro Max
# Discount                                      0
# discount percentage                         0.0
# Name: 323, dtype: object

# %%
sales_data.iloc[sales_data.iloc[:,7].idxmin()]
# Out:
# Brands                     Nokia
# Models                       105
# Colors                     Black
# Memory                      4 MB
# Storage                     4 MB
# Camera                       Yes
# Rating                       4.3
# Selling Price               1000
# Original Price              1000
# Mobile                 Nokia 105
# Discount                       0
# discount percentage          0.0
# Name: 1501, dtype: object

# %%
sales_data.loc[0:26]
# Out:
#       Brands             Models               Colors  Memory Storage Camera  \
# 0    SAMSUNG       GALAXY M31S          Mirage Black    8 GB  128 GB    Yes
# 1      Nokia                3.2                Steel    2 GB   16 GB    Yes
# 2     realme                C2         Diamond Black    2 GB     NaN    Yes
# 3    Infinix             Note 5             Ice Blue    4 GB   64 GB    Yes
# 4      Apple         iPhone 11                 Black     4GB   64 GB    Yes
# 5     GIONEE               L800                Black    8 MB   16 MB    Yes
# 6      Apple    iPhone 13 Mini                  Pink    6 GB  512 GB    Yes
# 7      Apple         iPhone XR                 Coral    3 GB   64 GB    Yes
# 8    SAMSUNG         Galaxy E5                 Brown  1.5 GB   16 GB    Yes
# 9     Xiaomi  Redmi Note 11T 5G      Aquamarine Blue    8 GB  128 GB    Yes
# 10   SAMSUNG        Galaxy A12                 Black    4 GB   64 GB    Yes
# ...

# %%
sales_data.isnull()
# Out:
#       Brands  Models  Colors  Memory  Storage  Camera  Rating  Selling Price  \
# 0      False   False   False   False    False   False   False          False
# 1      False   False   False   False    False   False   False          False
# 2      False   False   False   False     True   False   False          False
# 3      False   False   False   False    False   False   False          False
# 4      False   False   False   False    False   False   False          False
# ...      ...     ...     ...     ...      ...     ...     ...            ...
# 3109   False   False   False   False    False   False   False          False
# 3110   False   False   False    True    False   False   False          False
# 3111   False   False   False   False    False   False   False          False
# 3112   False   False   False   False    False   False    True          False
# 3113   False   False   False   False    False   False   False          False
#
# ...

# %%
sales_data["Memory"].fillna(sales_data["Memory"].mode()[0], inplace=True)
sales_data["Storage"].fillna(sales_data["Storage"].mode()[0], inplace=True)

print(sales_data[["Memory", "Storage"]].isnull().sum())
# Out:
# Memory     0
# Storage    0
# dtype: int64

# %%
sales_data.groupby('Brands')['Models'].value_counts()
# Out:
# Brands  Models
# ASUS    Zenfone Selfie         16
#         Zenfone Max Pro M1     10
#         Zenfone Go              8
#         6Z                      7
#         ZenFone Max M2          6
#                                ..
# vivo    Y83                     1
#         Y90                     1
#         Y91i                    1
#         Y93                     1
#         Y94                     1
# Name: count, Length: 928, dtype: int64

# %%
sales_data.groupby('Brands')['Discount'].max().sort_values()

# %%
sales_data.groupby('Brands')['Selling Price'].sum().sort_values(ascending=False)
# Out:
# Brands
# Apple           31728412
# SAMSUNG         17469003
# realme           5361667
# OPPO             4825727
# Xiaomi           3354498
# vivo             2959414
# ASUS             2398576
# Nokia            2008304
# LG               1912995
# Google Pixel     1780364
# Motorola         1717534
# Infinix          1674919
# HTC              1557291
# POCO             1248426
# Lenovo           1220145
# GIONEE            920427
# IQOO              185950
# Name: Selling Price, dtype: int64
