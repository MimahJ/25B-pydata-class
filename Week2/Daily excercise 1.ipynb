# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as pd
import pandas as pd

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
data = [
    {"name": "Bulbasaur", "evolution": "Ivysaur", "hp": 45, "pokedex": "yes", "type": "grass"},
    {"name": "Charmander", "evolution": "Charmeleon", "hp": 39, "pokedex": "no", "type": "fire"},
    {"name": "Squirtle", "evolution": "Wartortle", "hp": 44, "pokedex": "yes", "type": "water"},
    {"name": "Caterpie", "evolution": "Metapod", "hp": 45, "pokedex": "no", "type": "bug"}
]

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
pokemon = [
    {"name": "Bulbasaur", "evolution": "Ivysaur", "hp": 45, "pokedex": "yes", "type": "grass"},
    {"name": "Charmander", "evolution": "Charmeleon", "hp": 39, "pokedex": "no", "type": "fire"},
    {"name": "Squirtle", "evolution": "Wartortle", "hp": 44, "pokedex": "yes", "type": "water"},
    {"name": "Caterpie", "evolution": "Metapod", "hp": 45, "pokedex": "no", "type": "bug"}
]

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = [
    {"name": "Bulbasaur", "type": "grass", "hp": 45, "evolution": "Ivysaur", "pokedex": "yes"},
    {"name": "Charmander", "type": "fire", "hp": 39, "evolution": "Charmeleon", "pokedex": "no"},
    {"name": "Squirtle", "type": "water", "hp": 44, "evolution": "Wartortle", "pokedex": "yes"},
    {"name": "Caterpie", "type": "bug", "hp": 45, "evolution": "Metapod", "pokedex": "no"}
]

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon = [
    {"name": "Bulbasaur", "type": "grass", "hp": 45, "evolution": "Ivysaur", "pokedex": "yes", "place": "Forest"},
    {"name": "Charmander", "type": "fire", "hp": 39, "evolution": "Charmeleon", "pokedex": "no", "place": "Volcanic Region"},
    {"name": "Squirtle", "type": "water", "hp": 44, "evolution": "Wartortle", "pokedex": "yes", "place": "Lakes & Rivers"},
    {"name": "Caterpie", "type": "bug", "hp": 45, "evolution": "Metapod", "pokedex": "no", "place": "Grasslands"}
]

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
# Define the pokemon list
pokemon = [
    {"name": "Bulbasaur", "type": "grass", "hp": 45, "evolution": "Ivysaur", "pokedex": "yes", "place": "Forest"},
    {"name": "Charmander", "type": "fire", "hp": 39, "evolution": "Charmeleon", "pokedex": "no", "place": "Volcanic Region"},
    {"name": "Squirtle", "type": "water", "hp": 44, "evolution": "Wartortle", "pokedex": "yes", "place": "Lakes & Rivers"},
    {"name": "Caterpie", "type": "bug", "hp": 45, "evolution": "Metapod", "pokedex": "no", "place": "Grasslands"}
]

# Get data types of each column
column_types = {key: type(value).__name__ for key, value in pokemon[0].items()}

# Print the data types
print(column_types)
# Out:
# {'name': 'str', 'type': 'str', 'hp': 'int', 'evolution': 'str', 'pokedex': 'str', 'place': 'str'}

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
#  Find the pokemon with the highest HP

# %%
# Find the Pokémon with the highest HP
strongest_pokemon = max(pokemon, key=lambda p: p["hp"])

# Print the result
print(strongest_pokemon)
# Out:
# {'name': 'Bulbasaur', 'type': 'grass', 'hp': 45, 'evolution': 'Ivysaur', 'pokedex': 'yes', 'place': 'Forest'}
